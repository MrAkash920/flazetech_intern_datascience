# %% [markdown]
# # Flazetech Data Science Internship

# %% [markdown]
# ### Author : Akash Sigh
# ### Task: Iris Flower Classification

# %% [markdown]
# ### What is Classification
# Classification is a supervised machine learning method where the model tries to predict the correct label of a given input data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### To solve this task I will use here K-NN algorithm.
